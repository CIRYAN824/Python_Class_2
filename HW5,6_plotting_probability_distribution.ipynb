# %% [markdown]
# # HW 5

# %% [markdown]
# 자세한 사항은 week05_data_exploration.ipynb에 있는 과제 1, 2를 참조해주세요.

# %% [markdown]
# ## 과제 5-1.
# 우리는 지난 시간에 iris setosa에 대해 아래와 같은 plot들을 그렸습니다. iris versicolor, iris virginica에 대해서도 같은 plot 들을 그려봅시다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 과제 5-2.
# 우리는 지난 시간에 sepal length에 대해 아래와 같은 plot들을 그렸습니다. petal length에 대해서도 같은 plot 들을 그려봅시다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # HW 6

# %% [markdown]
# ## 과제 6-1.
# n값과 p값을 달리해가면서 Binomial distribution 그래프를 3개 겹쳐서 그려봅시다.

# %% [markdown]
# ## 과제 6-2.
# mu값과 sigma값을 달리해가면서 Normal distribution 그래프를 3개 겹쳐서 그려봅시다.

# %% [markdown]
# ## 과제 6-3.
# lambda값을 달리해가면서 Poisson distribution 그래프를 3개 연속으로 그려봅시다.
